# %%
import module1

module1.read_csv()
# Out:
# Found: Argentina
# Found: North America
# Found: Kenya
# 1960    NaN
# 1961    NaN
# 1962    NaN
# 1963    NaN
# 1964    NaN
# 1965    NaN
# 1966    NaN
# 1967    NaN
# 1968    NaN
# 1969    NaN
# 1970    NaN
# 1971    NaN
# 1972    NaN
# 1973    NaN
# 1974    NaN
# 1975    NaN
# 1976    NaN
# 1977    NaN
# 1978    NaN
# 1979    NaN
# 1980    0.4
# 1981    NaN
# 1982    NaN
# 1983    NaN
# 1984    NaN
# 1985    NaN
# 1986      0
# 1987      0
# 1988    NaN
# 1989    NaN
# 1990    NaN
# 1991    1.1
# 1992    2.1
# 1993    2.4
# 1994    2.3
# 1995    4.1
# 1996    4.6
# 1997    4.1
# 1998    4.6
# 1999    4.8
# 2000    5.7
# 2001    9.4
# 2002     14
# 2003      7
# 2004    5.4
# 2005    3.9
# 2006    3.3
# 2007    2.9
# 2008    2.6
# 2009    2.6
# 2010    1.1
# Name: 7, dtype: object
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# ...

# %%
module1.poverty_line_diagram()
# Out:
# Found: Argentina
# Found: North America
# Found: Kenya
# 1960    NaN
# 1961    NaN
# 1962    NaN
# 1963    NaN
# 1964    NaN
# 1965    NaN
# 1966    NaN
# 1967    NaN
# 1968    NaN
# 1969    NaN
# 1970    NaN
# 1971    NaN
# 1972    NaN
# 1973    NaN
# 1974    NaN
# 1975    NaN
# 1976    NaN
# 1977    NaN
# 1978    NaN
# 1979    NaN
# 1980    0.4
# 1981    NaN
# 1982    NaN
# 1983    NaN
# 1984    NaN
# 1985    NaN
# 1986      0
# 1987      0
# 1988    NaN
# 1989    NaN
# 1990    NaN
# 1991    1.1
# 1992    2.1
# 1993    2.4
# 1994    2.3
# 1995    4.1
# 1996    4.6
# 1997    4.1
# 1998    4.6
# 1999    4.8
# 2000    5.7
# 2001    9.4
# 2002     14
# 2003      7
# 2004    5.4
# 2005    3.9
# 2006    3.3
# 2007    2.9
# 2008    2.6
# 2009    2.6
# 2010    1.1
# Name: 7, dtype: object
